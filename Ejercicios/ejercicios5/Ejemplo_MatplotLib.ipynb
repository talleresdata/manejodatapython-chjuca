# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp

# %%
df = pd.read_json("data/log-course2.json")

# %%
df.head()
# Out:
#                        accept_language  \
# 0                       es-ES,es;q=0.9
# 1                       es-ES,es;q=0.9
# 2  es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3
# 3  es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3
# 4  es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3
#
#                                                agent  \
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 2  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:6...
# 3  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:6...
# 4  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:6...
#
#                                              context  \
# 0  {'course_user_tags': {}, 'user_id': '', 'org_i...
# 1  {'course_user_tags': {}, 'user_id': '', 'org_i...
# 2  {'course_user_tags': {}, 'user_id': '', 'org_i...
# 3  {'user_id': '', 'org_id': '', 'course_id': '',...
# 4  {'user_id': '', 'org_id': '', 'course_id': '',...
#
#                                                event event_source  \
# ...

# %%
df.keys()
# Out:
# Index(['accept_language', 'agent', 'context', 'event', 'event_source',
#        'event_type', 'host', 'ip', 'name', 'page', 'referer', 'session',
#        'time', 'username'],
#       dtype='object')

# %%
print(df.username.unique())
# Out:
# ['' 'danieltapia00' 'JocelyneCastillo' ... 'esbravo3' 'dmandrade1'
#  'KAELIZALDE']

# %%
df.username.value_counts()[:10].sort_values(inplace=False).plot('barh');

# %%
print(df.name.unique())
# Out:
# [nan 'edx.course.enrollment.activated' 'edx.course.enrollment.deactivated'
#  'page_close' 'load_video' 'play_video' 'pause_video' 'seek_video'
#  'edx.forum.thread.created' 'problem_check' 'problem_graded' 'seq_goto'
#  'edx.forum.response.created' 'problem_show' 'problem_save'
#  'edx.user.settings.changed' 'seq_next' 'seq_prev'
#  'edx.forum.comment.created' 'stop_video' 'edx.forum.searched'
#  'speed_change_video']

# %%
df.name.value_counts()[:20].sort_values(inplace=False).plot('barh');

# %%
df.agent.value_counts()[:20].sort_values(inplace=False).plot('barh');

# %%
df.accept_language.value_counts()[:20].sort_values(inplace=False).plot('barh');

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-5709978ae679> in <module>()
# ----> 1 df.time.plot('barh');
#
# c:\users\carlos juca\appdata\local\programs\python\python36-32\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2739                            colormap=colormap, table=table, yerr=yerr,
#    2740                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2741                            **kwds)
#    2742     __call__.__doc__ = plot_series.__doc__
#    2743
#
# ...

# %%
plt.plot(df.username.value_counts())
